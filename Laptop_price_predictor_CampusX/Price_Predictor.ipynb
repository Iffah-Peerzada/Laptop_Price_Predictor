# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("laptop_data.csv")
data.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
data.drop(columns  = ["Unnamed: 0"],inplace = True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
data['Ram'] = data['Ram'].str.replace('GB','')
data['Weight'] = data['Weight'].str.replace('kg','')

data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
data['Ram'] = data['Ram'].astype('int')
data['Weight'] = data['Weight'].astype('float')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\peerz\AppData\Local\Temp\ipykernel_6924\4196895882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=data['Company'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=data['TypeName'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=data['Inches'],y=data['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
data['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
data['Touchscreen'] = data['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
data['IPS'] = data['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
new = data['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
data['X_res'] = new[0]
data['Y_res'] = new[1]
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
data['X_res'] = data['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
data['X_res'] = data['X_res'].astype('int')
data['Y_res'] = data['Y_res'].astype('int')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# ...

# %%
num_data = data[['Inches','Weight','X_res','Y_res','Ram','Touchscreen','IPS','Price']]

num_data.corr()['Price']
# Out:
# Inches         0.068197
# Weight         0.210370
# X_res          0.556529
# Y_res          0.552809
# Ram            0.743007
# Touchscreen    0.191226
# IPS            0.252208
# Price          1.000000
# Name: Price, dtype: float64

# %%
# Creating a new column - PPI, Pixels per inches
# calculation =  [squ.root of (X_res squ. + Y_res squ.)] / inches

data['PPI'] = (((data['X_res']**2 + data['Y_res']**2)**0.5)/data['Inches']).astype('float')

num_data = data[['PPI','Inches','Weight','X_res','Y_res','Ram','Touchscreen','IPS','Price']]
num_data.corr()['Price']
# Out:
# PPI            0.473487
# Inches         0.068197
# Weight         0.210370
# X_res          0.556529
# Y_res          0.552809
# Ram            0.743007
# Touchscreen    0.191226
# IPS            0.252208
# Price          1.000000
# Name: Price, dtype: float64

# %%
data.drop(columns  = ['X_res','Y_res','Inches','ScreenResolution'],inplace = True)
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# ...

# %%
data['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
data['cpu_name'] = data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       cpu_name
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
data['CPU_Brand'] = data['cpu_name'].apply(fetch_processor)
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       cpu_name      CPU_Brand
# ...

# %%
data['CPU_Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='CPU_Brand'>

# %%
sns.barplot(x=data['CPU_Brand'],y=data['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
data.drop(columns=['Cpu','cpu_name'],inplace=True)
data.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI      CPU_Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
data['Memory'] = data['Memory'].astype(str).replace('\.0', '', regex = True)
data['Memory'] = data['Memory'].str.replace('GB','')
data['Memory'] = data['Memory'].str.replace('TB','000')

new = data['Memory'].str.split('+', n=1, expand = True)

data['first']=new[0]
data['first'] = data['first'].str.strip()
data['second'] = new[1]



data['Layer1HDD'] = data['first'].apply(lambda x: 1 if 'HDD' in x else 0)
data['Layer1SSD'] = data['first'].apply(lambda x: 1 if 'SSD' in x else 0)
data['Layer1Hybrid'] = data['first'].apply(lambda x: 1 if 'Hybrid' in x else 0)
data['Layer1Flash'] = data['first'].apply(lambda x: 1 if 'Flash' in x else 0)

data['first'] = data['first'].str.replace(r'\D', '',regex=True)



data['second'].fillna('0',inplace=True)

data['Layer2HDD'] = data['second'].apply(lambda x: 1 if 'HDD' in x else 0)
data['Layer2SSD'] = data['second'].apply(lambda x: 1 if 'SSD' in x else 0)
data['Layer2Hybrid'] = data['second'].apply(lambda x: 1 if 'Hybrid' in x else 0)
data['Layer2Flash'] = data['second'].apply(lambda x: 1 if 'Flash' in x else 0)

data['second'] = data['second'].str.replace(r'\D', '',regex=True)



data['first'] = data['first'].astype(int)
data['second'] = data['second'].astype(int)

data['HDD'] = (data['first'] * data['Layer1HDD'] + data['second'] * data['Layer2HDD'])
data['SSD'] = (data['first'] * data['Layer1SSD'] + data['second'] * data['Layer2SSD'])
data['Flash_Storage'] = (data['first'] * data['Layer1Flash'] + data['second'] * data['Layer2Flash'])
data['Hybrid'] = (data['first'] * data['Layer1Hybrid'] + data['second'] * data['Layer2Hybrid'])



data.drop(columns=['Memory','first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash','Layer2HDD','Layer2Hybrid','Layer2SSD','Layer2Flash'],inplace=True)
data.head(10)
# Out:
#   Company   TypeName  Ram                           Gpu       OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640       macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000       macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620       No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455       macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650       macOS    1.37
# 5    Acer   Notebook    4                 AMD Radeon R5  Windows 10    2.10
# 6   Apple  Ultrabook   16       Intel Iris Pro Graphics    Mac OS X    2.04
# 7   Apple  Ultrabook    8        Intel HD Graphics 6000       macOS    1.34
# 8    Asus  Ultrabook   16          Nvidia GeForce MX150  Windows 10    1.30
# 9    Acer  Ultrabook    8        Intel UHD Graphics 620  Windows 10    1.60
#
#          Price  Touchscreen  IPS         PPI      CPU_Brand  HDD  SSD  \
# ...

# %%
num_data = data[['HDD','SSD','Flash_Storage','Hybrid','PPI','Weight','Ram','Touchscreen','IPS','Price']]
num_data.corr()['Price']
# Out:
# HDD             -0.096441
# SSD              0.670799
# Flash_Storage   -0.040511
# Hybrid           0.007989
# PPI              0.473487
# Weight           0.210370
# Ram              0.743007
# Touchscreen      0.191226
# IPS              0.252208
# Price            1.000000
# Name: Price, dtype: float64

# %%
data.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
data.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI      CPU_Brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
data['Gpu_Brand'] = data['Gpu'].apply(lambda x: x.split()[0])
data['Gpu_Graphic'] = data['Gpu'].apply(lambda x: 1 if 'Graphic' in x else 0)

data.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI      CPU_Brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu_Brand  Gpu_Graphic
# 0     Intel            1
# 1     Intel            1
# 2     Intel            1
# ...

# %%
num_data = data[['Gpu_Graphic','HDD','SSD','PPI','Weight','Ram','Touchscreen','IPS','Price']]
num_data.corr()['Price']
# Out:
# Gpu_Graphic   -0.202545
# HDD           -0.096441
# SSD            0.670799
# PPI            0.473487
# Weight         0.210370
# Ram            0.743007
# Touchscreen    0.191226
# IPS            0.252208
# Price          1.000000
# Name: Price, dtype: float64

# %%
data['Gpu_Brand'].value_counts()
# Out:
# Gpu_Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
# 3 main types of Gpus brands, and a single ARM laptop, 
# we will remove that laptop from dataset

data = data[data['Gpu_Brand'] != 'ARM']
data['Gpu_Brand'].value_counts()
# Out:
# Gpu_Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
data.drop(columns=['Gpu'],inplace=True)

# %%
data.sample(10)
# Out:
#      Company            TypeName  Ram       OpSys  Weight       Price  \
# 1266      HP            Notebook    6  Windows 10    2.04  29303.4672
# 283   Lenovo            Notebook    6  Windows 10    2.20  30849.1200
# 1123    Dell            Notebook    4       Linux    2.09  27899.0064
# 124     Acer            Notebook    4  Windows 10    2.10  24029.2800
# 294   Lenovo            Notebook    8  Windows 10    2.05  39373.9200
# 392     Acer            Notebook   12  Windows 10    2.20  36975.7872
# 767     Dell              Gaming   16  Windows 10    2.72  58554.7200
# 38        HP            Notebook    4  Windows 10    1.86  26037.4032
# 592     Dell  2 in 1 Convertible    4  Windows 10    1.39  32127.8400
# 407     Dell           Ultrabook    8  Windows 10    1.36  89510.4000
#
#       Touchscreen  IPS         PPI              CPU_Brand   HDD  SSD  \
# 1266            0    0  141.211998          AMD Processor     0    0
# ...

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=data['OpSys'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
def cat_os(name):
    if name == 'No OS' or name == 'Chrome OS' or name == 'Android':
        return 'Chrome/Android/None'
    
    elif name == 'Windows 10' or name == 'Windows 10 S' or name == 'Windows 7':
        return 'Windows'

    elif name == 'macOS' or name == 'Mac OS X':
        return 'Mac'

    elif name == 'Linux':
        return 'Linux'

# %%
data['Op_Sys'] = data['OpSys'].apply(cat_os)

# %%
data['Op_Sys'].value_counts()
# Out:
# Op_Sys
# Windows                1125
# Chrome/Android/None      94
# Linux                    62
# Mac                      21
# Name: count, dtype: int64

# %%
sns.barplot(x=data['Op_Sys'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
data.drop(columns=['OpSys'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        CPU_Brand  HDD  SSD Gpu_Brand  Gpu_Graphic               Op_Sys
# 0  Intel Core i5    0  128     Intel            1                  Mac
# 1  Intel Core i5    0    0     Intel            1                  Mac
# 2  Intel Core i5    0  256     Intel            1  Chrome/Android/None
# 3  Intel Core i7    0  512       AMD            0                  Mac
# 4  Intel Core i5    0  256     Intel            1                  Mac

# %%
sns.distplot(data['Weight'])
# Out:
# C:\Users\peerz\AppData\Local\Temp\ipykernel_6924\2799343561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.heatmap(num_data.corr())

# If you find a square thats too light and not in the Price columns,
# Remove one of the features from the 2 that make the light square
# Out:
# <Axes: >

# %%
# Applying log transformation to remove skewness of target column (Price)

sns.distplot(np.log(data['Price']))
# Out:
# C:\Users\peerz\AppData\Local\Temp\ipykernel_6924\3313909972.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# Data preparation and relevant package imports

# -- Do Hyper Parameter Tuning for all models --- 

# --- Do Scaling and Feature Selection if needed -- 

from sklearn.model_selection import train_test_split

# To transform the Categorical columns
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

#ML Models
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor 
from sklearn.svm import SVR
#from xgboost import XGBRegressor

# Metrics
from sklearn.metrics import r2_score,mean_absolute_error

Y = np.log(data['Price'])
X = data.drop(columns = ['Price']) # 12 columns


X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)


# Identify categorical columns
cat_columns = X.select_dtypes(include=['object']).columns

# %%
# Model 1 : Linear reggresion
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = LinearRegression()

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 Score 0.7997707553259824
# Mean absolute error 0.2039599402237761
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
np.exp(0.21)
# Out:
# 1.2336780599567432

# %%
# Model 2 : Ridge reggresion
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = Ridge(alpha = 20)

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 Score 0.8000649043317679
# Mean absolute error 0.2053641223950408
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Model 3 : Lasso reggresion
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = Lasso(alpha = 0.001)

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 Score 0.7978388984787483
# Mean absolute error 0.20627529826761015
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Model 4: K nearest neighbor
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = KNeighborsRegressor(n_neighbors = 4)

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 Score 0.7914032859374066
# Mean absolute error 0.2012006611588582
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Model 5: Decision Tree
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = DecisionTreeRegressor(max_depth = 8)
# try tweaking more parameters 
# experiment and see if you can increase score

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 Score 0.7971916114955039
# Mean absolute error 0.200535373627639
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Model 6: SVM
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = SVR(kernel = 'rbf', C=10000, epsilon=0.3)
# Tweak more features, 
# experiment and see if you can increase score

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score 0.8041642092588681
# Mean absolute error 0.20370329208781662

# %%
# Model 7: Random Forest
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = RandomForestRegressor(n_estimators = 100,
                             random_state = 4,
                             max_samples=0.5,
                             max_features=0.75,
                             max_depth=15)
# Tweak more features, 
# experiment and see if you can increase score

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score 0.8691629580713293
# Mean absolute error 0.16483935590164975

# %%
# Model 8: Ada boost
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = AdaBoostRegressor(n_estimators = 15,learning_rate=1.0)
# Tweak more features, 
# experiment and see if you can increase score

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 Score 0.776919814059164
# Mean absolute error 0.22790708508110286
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Model 8: Gradient Boost
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = GradientBoostingRegressor(n_estimators = 500)
# Tweak more features, 
# experiment and see if you can increase score

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score 0.8638197939861789
# Mean absolute error 0.1602165785512036

# %%
# Model 9: Extra Tree
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    
],remainder='passthrough')
            
step2 = ExtraTreesRegressor(n_estimators = 100,
                           random_state = 3,
                           max_features = 0.75,
                           max_depth = 10)
# try tweaking more parameters 
# experiment and see if you can increase score

pipe = Pipeline([
                              
    ('step 1',step1),
    ('step 2',step2)
                          ])
                          
pipe.fit(X_train, Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score 0.8554834864884114
# Mean absolute error 0.17099303016978526

# %%
from sklearn.ensemble import VotingRegressor, StackingRegressor

# --- Voting ---
# Combinig the best Models and giving the results of each some weight
# based on performance


# try tweaking more parameters 
# experiment and see if you can increase score

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    ],remainder='passthrough')


gbt = GradientBoostingRegressor(n_estimators = 500)
et =  ExtraTreesRegressor(n_estimators = 100, random_state = 3, max_features = 0.75, max_depth = 10)
rf = RandomForestRegressor(n_estimators = 100, random_state = 4, max_samples=0.5, max_features=0.75, max_depth=15)

step2 = VotingRegressor([('rf',rf), ('gbt',gbt), ('et',et)], weights=(5,1,1))

pipe = Pipeline([
    ('step 1 ', step1),
    ('step 2 ', step2)  ])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score 0.8733374406662442
# Mean absolute error 0.16084878252567808

# %%
# --- Stacking ---
# Placing Models sequencially to get a better result
# based on performance


# try tweaking more parameters 
# experiment and see if you can increase score


step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),cat_columns)
    ],remainder='passthrough')

estimators = [
    ('gbt', GradientBoostingRegressor(n_estimators = 500)),
    ('et', ExtraTreesRegressor(n_estimators = 100, random_state = 3, max_features = 0.75, max_depth = 10)),
    ('rf', RandomForestRegressor(n_estimators = 100, random_state = 4, max_samples=0.5, max_features=0.75, max_depth=15))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step 1 ', step1),
    ('step 2 ', step2)  ])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 Score',r2_score(Y_test,Y_pred))
print('Mean absolute error',mean_absolute_error(Y_test,Y_pred))
# Out:
# C:\Users\peerz\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score 0.8706492866090746
# Mean absolute error 0.16157153344364256

# %%
import pickle

# Exports the chosen files, objects, etc into Jupyter folder and Documents

pickle.dump(data,open('Laptop_data.pkl', 'wb'))
pickle.dump(pipe,open('pipe.pkl', 'wb'))
